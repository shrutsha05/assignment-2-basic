# %%
1:
the two values are true and false. It can be compared using comparision operation
2:
they are AND, OR & NOT
3
and
true and true = true
true and false = false
false and true = false
false and false = false

or 
true or true = true
true or false= true
false or true = true
false or false = false

not 
not true = false
not false = true

4:
False
true
false
true
false

5:
<greater
> less
== equal equal to
!= not equal to
<= grater than
>= less than
6:
the difference is that for assigning is single = and for equal to we use==
for eg:
    a=5 this is an assignment operator here we have used single = 
    for a==b this used as an operator equal

7:
spam = 0 //block 1 assigning

//if spam == 10:
print('eggs')
if spam > 5:
  print('bacon')
else:
   print('ham')// block 2 conditional check

//print('spam')
print('spam')// block 3

8:

spam = int(input())

if spam == 1:  
    
  print('Hello')
      
elif spam == 2:
      
  print('Howdy')
      
else:
    
  print('Greetings!')

9:

ctrl+C

10:
Break will get you out of the loop in which the break statement
continue will only skip a single iteration

11:
    
range(10): it means that the loop will go till 10. but it will execute till 9 as upper bond is excluded is the stop value of the loop that means once 10 value comes the loop will end
range(0,10): it means that 0 is the start value of the loop and 9 is the stop value of the loop this loop will execute from 0 to 10 as soon as 10 come it will end 
range(0,10,1): it means that 0 is the start point of loop 10 is the stop and 1 is the step size that means that after 0 it will print 1 as the step jump is one and it will continue till 10 and then end
    
    
12:

for i in range(1,11):
    
while

a = 1
while a <=10:
    print(a)
    a = a+1

13:
    spam.bacon()
